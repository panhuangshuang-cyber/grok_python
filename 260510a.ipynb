# %%
import pandas as pd
import numpy as np
import polars as pl

# %%
2+3

# %%
import os
from pathlib import Path

root = Path(r"E:\grok_python\cache")
root.mkdir(parents=True, exist_ok=True)

# 创建必要文件（占位内容，可后续替换）
(root / "constant_var.py").write_text("# 常量定义\nCACHE_ROOT = r'E:\\grok_python\\cache'\n", encoding="utf-8")
(root / "data_setup.py").write_text("# 数据初始化\nprint('data setup ready')\n", encoding="utf-8")
(root / "__init__.py").write_text("", encoding="utf-8")

# pyproject.toml（现代包安装）
(root / "pyproject.toml").write_text("""[project]
name = "grok-cache-pkg"
version = "0.1.0"
dependencies = []

[tool.setuptools.packages.find]
where = ["."]
""", encoding="utf-8")

print("✅ 包已创建！")
print("下一步：在命令行执行：")
print(f"cd {root}")
print("pip install -e .")

# %%
from data_setup import *
connMy
# Out:
# data setup ready
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 from data_setup import *
# ----> 2 connMy
#
# NameError: name 'connMy' is not defined

# %%
2+3
# Out:
# 5
